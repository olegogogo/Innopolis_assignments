# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(1,50,500)
x = np.sin(t)
y = np.cos(t)

# %%
plt.plot(x,y)
plt.show()

# %%
import sympy

# %%
x1, x2, x3 = sympy.symbols('x1 x2 x3')
a, b, c, d, e, f, g ,h ,i , j = sympy.symbols('a b c d e f g h i j')
x = sympy.Matrix([[x1,x2,x3]])
Q = sympy.Matrix([[a,b,c],[d,e,f],[h,i,j]])

# %%
(x * Q * x.T)
# Out:
# Matrix([[x1*(a*x1 + d*x2 + h*x3) + x2*(b*x1 + e*x2 + i*x3) + x3*(c*x1 + f*x2 + j*x3)]])

# %%
y = 10*x1**2 + 9*x2**2 + x1*x2
# Out:
# 10*x1**2 + x1*x2 + 9*x2**2

# %%
t = np.linspace(1,200,500)
x1 = np.linspace(1,50,500)
x2 = np.linspace(1,20,500)
y = []
for i,j in zip(x1,x2):
    yi = 10*i**2 + 9*j**2 + i*j
    y.append(yi)

# %%
plt.plot(t,y)
plt.show()
